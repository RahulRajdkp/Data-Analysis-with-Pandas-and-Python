# %% [markdown]
# # Data Analysis with Python  (Udemy)

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
# %config Completer.use_jedi = False # to activate autocomplete

# %%
bbt = ["Sheldon","Amy","Leonard","Penny","Howard","Bernedette","Raj","Emiley"]
bbt
# Out:
# ['Sheldon', 'Amy', 'Leonard', 'Penny', 'Howard', 'Bernedette', 'Raj', 'Emiley']

# %%
bbt[1:3]
# Out:
# ['Amy', 'Leonard']

# %%
bbt[:4]
# Out:
# ['Sheldon', 'Amy', 'Leonard', 'Penny']

# %% [markdown]
# # Series: 1D labelled array

# %%
pd.Series(bbt)
# Out:
# 0       Sheldon
# 1           Amy
# 2       Leonard
# 3         Penny
# 4        Howard
# 5    Bernedette
# 6           Raj
# 7        Emiley
# dtype: object

# %%
bbt_s=pd.Series(bbt)
bbt_s
# Out:
# 0       Sheldon
# 1           Amy
# 2       Leonard
# 3         Penny
# 4        Howard
# 5    Bernedette
# 6           Raj
# 7        Emiley
# dtype: object

# %%
bbt_s.values
# Out:
# array(['Sheldon', 'Amy', 'Leonard', 'Penny', 'Howard', 'Bernedette',
#        'Raj', 'Emiley'], dtype=object)

# %%
bbt_s.sort_values #(ascending = False)
# Out:
# <bound method Series.sort_values of 0       Sheldon
# 1           Amy
# 2       Leonard
# 3         Penny
# 4        Howard
# 5    Bernedette
# 6           Raj
# 7        Emiley
# dtype: object>

# %%
bbt_s.head()
# Out:
# 0    Sheldon
# 1        Amy
# 2    Leonard
# 3      Penny
# 4     Howard
# dtype: object

# %%
s = pd.read_csv(r"C:\Users\RAHUL RAJ\Desktop\ML_Practise\usedcarsdataset_clean.csv",squeeze = True, usecols=['make','fuel-type','price'])
s.head(3)
# Out:
#           make fuel-type    price
# 0  alfa-romero       gas  13495.0
# 1  alfa-romero       gas  16500.0
# 2  alfa-romero       gas  16500.0

# %%
ss = pd.Series(s['price'])
ss
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 188    16845.0
# 189    19045.0
# 190    21485.0
# 191    22470.0
# 192    22625.0
# Name: price, Length: 193, dtype: float64

# %%
ss.apply(lambda price:price + 2)
# Out:
# 0      13497.0
# 1      16502.0
# 2      16502.0
# 3      13952.0
# 4      17452.0
#         ...
# 188    16847.0
# 189    19047.0
# 190    21487.0
# 191    22472.0
# 192    22627.0
# Name: price, Length: 193, dtype: float64

# %%
s['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
s['make'].nunique()
# Out:
# 21

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   make       193 non-null    object
#  1   fuel-type  193 non-null    object
#  2   price      193 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 4.6+ KB

# %%
s['fuel-type'] = s['fuel-type'] .astype ("category")

# %%
 s.info()    # decreases the memory usage #used for categorical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   make       193 non-null    object
#  1   fuel-type  193 non-null    category
#  2   price      193 non-null    float64
# dtypes: category(1), float64(1), object(1)
# memory usage: 3.4+ KB

# %%
 s.sort_values('make',ascending = False)  #if Nan is ther it will be placed at end or use na_position = T/F
# Out:
#             make fuel-type    price
# 192        volvo       gas  22625.0
# 187        volvo       gas  18950.0
# 182        volvo       gas  12940.0
# 183        volvo       gas  13415.0
# 184        volvo       gas  15985.0
# ..           ...       ...      ...
# 4           audi       gas  17450.0
# 3           audi       gas  13950.0
# 2    alfa-romero       gas  16500.0
# 1    alfa-romero       gas  16500.0
# 0    alfa-romero       gas  13495.0
#
# [193 rows x 3 columns]

# %%
s.sort_values(['make','price'])
# Out:
#             make fuel-type    price
# 0    alfa-romero       gas  13495.0
# 1    alfa-romero       gas  16500.0
# 2    alfa-romero       gas  16500.0
# 3           audi       gas  13950.0
# 5           audi       gas  15250.0
# ..           ...       ...      ...
# 187        volvo       gas  18950.0
# 189        volvo       gas  19045.0
# 190        volvo       gas  21485.0
# 191        volvo    diesel  22470.0
# 192        volvo       gas  22625.0
#
# [193 rows x 3 columns]

# %%
s.sort_values(['make','price'], ascending = [True,False]) # make is sorted ascending and price in descending
# Out:
#             make fuel-type    price
# 1    alfa-romero       gas  16500.0
# 2    alfa-romero       gas  16500.0
# 0    alfa-romero       gas  13495.0
# 8           audi       gas  23875.0
# 7           audi       gas  18920.0
# ..           ...       ...      ...
# 188        volvo       gas  16845.0
# 185        volvo       gas  16515.0
# 184        volvo       gas  15985.0
# 183        volvo       gas  13415.0
# 182        volvo       gas  12940.0
#
# [193 rows x 3 columns]

# %% [markdown]
# **pd.todatetime(df['Column'])** #to convert to datetime64

# %% [markdown]
# pd.read_csv("",parse_dates=['column'])

# %%
s['make'] == 'audi'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: make, Length: 193, dtype: bool

# %%
s [s['make'] == 'audi'] # only audi is listed # Also != , >, < ,<= , <=
# Out:
#    make fuel-type    price
# 3  audi       gas  13950.0
# 4  audi       gas  17450.0
# 5  audi       gas  15250.0
# 6  audi       gas  17710.0
# 7  audi       gas  18920.0
# 8  audi       gas  23875.0

# %%
a = s['make'] == 'audi'
f = s['fuel-type'] =='gas'

s[a & f] # both conditions should be true
# Out:
#    make fuel-type    price
# 3  audi       gas  13950.0
# 4  audi       gas  17450.0
# 5  audi       gas  15250.0
# 6  audi       gas  17710.0
# 7  audi       gas  18920.0
# 8  audi       gas  23875.0

# %%
p =  s['price'] > 20000

s[a | p] # either or
# Out:
#               make fuel-type    price
# 3             audi       gas  13950.0
# 4             audi       gas  17450.0
# 5             audi       gas  15250.0
# 6             audi       gas  17710.0
# 7             audi       gas  18920.0
# 8             audi       gas  23875.0
# 11             bmw       gas  20970.0
# 12             bmw       gas  21105.0
# 13             bmw       gas  24565.0
# 14             bmw       gas  30760.0
# 15             bmw       gas  41315.0
# 16             bmw       gas  36880.0
# 43          jaguar       gas  32250.0
# 44          jaguar       gas  35550.0
# 45          jaguar       gas  36000.0
# 58   mercedes-benz    diesel  25552.0
# 59   mercedes-benz    diesel  28248.0
# 60   mercedes-benz    diesel  28176.0
# 61   mercedes-benz    diesel  31600.0
# 62   mercedes-benz       gas  34184.0
# 63   mercedes-benz       gas  35056.0
# 64   mercedes-benz       gas  40960.0
# 65   mercedes-benz       gas  45400.0
# 116        porsche       gas  22018.0
# ...

# %%
s [ (a & f) | p]
# Out:
#               make fuel-type    price
# 3             audi       gas  13950.0
# 4             audi       gas  17450.0
# 5             audi       gas  15250.0
# 6             audi       gas  17710.0
# 7             audi       gas  18920.0
# 8             audi       gas  23875.0
# 11             bmw       gas  20970.0
# 12             bmw       gas  21105.0
# 13             bmw       gas  24565.0
# 14             bmw       gas  30760.0
# 15             bmw       gas  41315.0
# 16             bmw       gas  36880.0
# 43          jaguar       gas  32250.0
# 44          jaguar       gas  35550.0
# 45          jaguar       gas  36000.0
# 58   mercedes-benz    diesel  25552.0
# 59   mercedes-benz    diesel  28248.0
# 60   mercedes-benz    diesel  28176.0
# 61   mercedes-benz    diesel  31600.0
# 62   mercedes-benz       gas  34184.0
# 63   mercedes-benz       gas  35056.0
# 64   mercedes-benz       gas  40960.0
# 65   mercedes-benz       gas  45400.0
# 116        porsche       gas  22018.0
# ...

# %%
s [ s['make'].isin(['volvo','jaguar']) ]
# Out:
#        make fuel-type    price
# 43   jaguar       gas  32250.0
# 44   jaguar       gas  35550.0
# 45   jaguar       gas  36000.0
# 182   volvo       gas  12940.0
# 183   volvo       gas  13415.0
# 184   volvo       gas  15985.0
# 185   volvo       gas  16515.0
# 186   volvo       gas  18420.0
# 187   volvo       gas  18950.0
# 188   volvo       gas  16845.0
# 189   volvo       gas  19045.0
# 190   volvo       gas  21485.0
# 191   volvo    diesel  22470.0
# 192   volvo       gas  22625.0

# %%
s [ s['price'].between(20000, 30000)]
# Out:
#               make fuel-type    price
# 8             audi       gas  23875.0
# 11             bmw       gas  20970.0
# 12             bmw       gas  21105.0
# 13             bmw       gas  24565.0
# 58   mercedes-benz    diesel  25552.0
# 59   mercedes-benz    diesel  28248.0
# 60   mercedes-benz    diesel  28176.0
# 116        porsche       gas  22018.0
# 190          volvo       gas  21485.0
# 191          volvo    diesel  22470.0
# 192          volvo       gas  22625.0

# %%
s.drop_duplicates(['make'], keep = 'first') #only keeps first occurence  # last also if FAlse only rows that arre very unique
# Out:
#               make fuel-type    price
# 0      alfa-romero       gas  13495.0
# 3             audi       gas  13950.0
# 9              bmw       gas  16430.0
# 17       chevrolet       gas   5151.0
# 20           dodge       gas   5572.0
# 28           honda       gas   6479.0
# 41           isuzu       gas   6785.0
# 43          jaguar       gas  32250.0
# 46           mazda       gas   5195.0
# 58   mercedes-benz    diesel  25552.0
# 66         mercury       gas  16503.0
# 67      mitsubishi       gas   5389.0
# 80          nissan       gas   5499.0
# 98          peugot       gas  11900.0
# 109       plymouth       gas   5572.0
# 116        porsche       gas  22018.0
# 120           saab       gas  11850.0
# 126         subaru       gas   5118.0
# 138         toyota       gas   5348.0
# 170     volkswagen    diesel   7775.0
# 182          volvo       gas  12940.0

# %%
jb = pd.read_csv(r"C:\Users\RAHUL RAJ\Desktop\ML_Practise\jamesbonddata.csv")
jb.head(5)
# Out:
#                     Film  Year  Years lapse    Bond actor  \
# 0                 Dr. No  1962          NaN  Sean Connery
# 1  From Russia With Love  1963          1.0  Sean Connery
# 2             Goldfinger  1964          1.0  Sean Connery
# 3            Thunderball  1965          1.0  Sean Connery
# 4    You Only Live Twice  1967          2.0  Sean Connery
#
#    Bond actor appearance  Villians Dispatched  Others' Dispatched  \
# 0                      1                    4                   8
# 1                      2                   11                  16
# 2                      3                    9                  68
# 3                      4                   20                  90
# 4                      5                   21                 175
#
#    Total Dispatched  Adjusted box office  Actual box office  ...  \
# 0                12                448.8               59.5  ...
# 1                27                543.8               78.9  ...
# ...

# %% [markdown]
# **To make a column serve as index**

# %%
jb.set_index(keys ="Film",inplace = True)

# %%
jb.head()
# Out:
#                        Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Dr. No                 1962          NaN  Sean Connery                      1
# From Russia With Love  1963          1.0  Sean Connery                      2
# Goldfinger             1964          1.0  Sean Connery                      3
# Thunderball            1965          1.0  Sean Connery                      4
# You Only Live Twice    1967          2.0  Sean Connery                      5
#
#                        Villians Dispatched  Others' Dispatched  \
# Film
# Dr. No                                   4                   8
# From Russia With Love                   11                  16
# Goldfinger                               9                  68
# Thunderball                             20                  90
# You Only Live Twice                     21                 175
#
#                        Total Dispatched  Adjusted box office  \
# Film
# ...

# %% [markdown]
# **To reset index**

# %%
jb.reset_index()
jb.head()
# Out:
#                        Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Dr. No                 1962          NaN  Sean Connery                      1
# From Russia With Love  1963          1.0  Sean Connery                      2
# Goldfinger             1964          1.0  Sean Connery                      3
# Thunderball            1965          1.0  Sean Connery                      4
# You Only Live Twice    1967          2.0  Sean Connery                      5
#
#                        Villians Dispatched  Others' Dispatched  \
# Film
# Dr. No                                   4                   8
# From Russia With Love                   11                  16
# Goldfinger                               9                  68
# Thunderball                             20                  90
# You Only Live Twice                     21                 175
#
#                        Total Dispatched  Adjusted box office  \
# Film
# ...

# %% [markdown]
# **To change index from 1 column to another**

# %%
# first reset it with inplace

jb.reset_index(inplace=True)

# %%
#now set it to new column
jb.set_index(keys= "Year",inplace = True)
jb.head(2)
# Out:
#                        Film  Years lapse    Bond actor  Bond actor appearance  \
# Year
# 1962                 Dr. No          NaN  Sean Connery                      1
# 1963  From Russia With Love          1.0  Sean Connery                      2
#
#       Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Year
# 1962                    4                   8                12
# 1963                   11                  16                27
#
#       Adjusted box office  Actual box office  Adjusted budget  ...  \
# Year                                                           ...
# 1962                448.8               59.5              7.0  ...
# 1963                543.8               78.9             12.6  ...
#
#       Golden Globe wins Academy Award nominations Academy Award wins  \
# Year
# 1962                  1                         0                  0
# 1963                  0                         0                  0
#
# ...

# %%
jb.reset_index(inplace=True)
jb.set_index(keys= "Film",inplace = True)
jb.head(2)
# Out:
#                        Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Dr. No                 1962          NaN  Sean Connery                      1
# From Russia With Love  1963          1.0  Sean Connery                      2
#
#                        Villians Dispatched  Others' Dispatched  \
# Film
# Dr. No                                   4                   8
# From Russia With Love                   11                  16
#
#                        Total Dispatched  Adjusted box office  \
# Film
# Dr. No                               12                448.8
# From Russia With Love                27                543.8
#
#                        Actual box office  Adjusted budget  ...  \
# Film                                                       ...
# Dr. No                              59.5              7.0  ...
# From Russia With Love               78.9             12.6  ...
#
#                        Golden Globe wins Academy Award nominations  \
# ...

# %%
jb.sort_index(inplace=True)

# %% [markdown]
# **loc - using index variables**

# %%
jb.loc["GoldenEye"]  # only when we use the index column
# Out:
# Year                                         1995
# Years lapse                                     6
# Bond actor                         Pierce Brosnan
# Bond actor appearance                           1
# Villians Dispatched                            47
# Others' Dispatched                             25
# Total Dispatched                               72
# Adjusted box office                         518.5
# Actual box office                           351.9
# Adjusted budget                              76.9
# Actual budget                                  60
# Director                          Martin Campbell
# Rotten Tomatoes critic score                  82%
# Rotten Tomatoes audience score                83%
# Golden Globe nominations                        0
# Golden Globe wins                               0
# Academy Award nominations                       0
# Academy Award wins                              0
# Number of Bond drinks                           8
# ...

# %%
jb.loc["GoldenEye" :"Moonraker"]
# From  goldeneye to moonraker in the sorted list
# Out:
#                   Year  Years lapse      Bond actor  Bond actor appearance  \
# Film
# GoldenEye         1995          6.0  Pierce Brosnan                      1
# Goldfinger        1964          1.0    Sean Connery                      3
# Licence to Kill   1989          2.0  Timothy Dalton                      2
# Live and Let Die  1973          2.0     Roger Moore                      1
# Moonraker         1979          2.0     Roger Moore                      4
#
#                   Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# GoldenEye                          47                  25                72
# Goldfinger                          9                  68                77
# Licence to Kill                    10                  13                23
# Live and Let Die                    8                   5                13
# Moonraker                          12                  69                81
#
# ...

# %%
jb.loc["GoldenEye" :"Moonraker":2]
# From  goldeneye to moonraker  and size = 2 in the sorted list
# Out:
#                  Year  Years lapse      Bond actor  Bond actor appearance  \
# Film
# GoldenEye        1995          6.0  Pierce Brosnan                      1
# Licence to Kill  1989          2.0  Timothy Dalton                      2
# Moonraker        1979          2.0     Roger Moore                      4
#
#                  Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# GoldenEye                         47                  25                72
# Licence to Kill                   10                  13                23
# Moonraker                         12                  69                81
#
#                  Adjusted box office  Actual box office  Adjusted budget  ...  \
# Film                                                                      ...
# GoldenEye                      518.5              351.9             76.9  ...
# Licence to Kill                250.9              156.2             56.7  ...
# ...

# %% [markdown]
# **iloc- using index positions**

# %%
jb.iloc[0]
# Out:
# Year                                     1985
# Years lapse                                 2
# Bond actor                        Roger Moore
# Bond actor appearance                       7
# Villians Dispatched                         5
# Others' Dispatched                         57
# Total Dispatched                           62
# Adjusted box office                     275.2
# Actual box office                       152.4
# Adjusted budget                          54.5
# Actual budget                              30
# Director                            John Glen
# Rotten Tomatoes critic score              34%
# Rotten Tomatoes audience score            41%
# Golden Globe nominations                    1
# Golden Globe wins                           0
# Academy Award nominations                   0
# Academy Award wins                          0
# Number of Bond drinks                    14.5
# Bond girls                                  4
# ...

# %%
jb.iloc[4:8] # doesnot include 8
# Out:
#                        Year  Years lapse      Bond actor  \
# Film
# Dr. No                 1962          NaN    Sean Connery
# For Your Eyes Only     1981          2.0     Roger Moore
# From Russia With Love  1963          1.0    Sean Connery
# GoldenEye              1995          6.0  Pierce Brosnan
#
#                        Bond actor appearance  Villians Dispatched  \
# Film
# Dr. No                                     1                    4
# For Your Eyes Only                         5                   18
# From Russia With Love                      2                   11
# GoldenEye                                  1                   47
#
#                        Others' Dispatched  Total Dispatched  \
# Film
# Dr. No                                  8                12
# For Your Eyes Only                     36                54
# From Russia With Love                  16                27
# GoldenEye                              25                72
#
# ...

# %%
jb.iloc[[3,4,5]]
# Out:
#                     Year  Years lapse      Bond actor  Bond actor appearance  \
# Film
# Die Another Day     2002          3.0  Pierce Brosnan                      4
# Dr. No              1962          NaN    Sean Connery                      1
# For Your Eyes Only  1981          2.0     Roger Moore                      5
#
#                     Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# Die Another Day                      31                  20                51
# Dr. No                                4                   8                12
# For Your Eyes Only                   18                  36                54
#
#                     Adjusted box office  Actual box office  Adjusted budget  \
# Film
# Die Another Day                   465.4              431.9            154.2
# Dr. No                            448.8               59.5              7.0
# For Your Eyes Only                449.4              194.9             60.2
#
# ...

# %%
jb.loc['GoldenEye',"Year"]
# Out:
# 1995

# %%
jb.loc['GoldenEye',"Year":"Bond actor"]
# Out:
# Year                     1995
# Years lapse                 6
# Bond actor     Pierce Brosnan
# Name: GoldenEye, dtype: object

# %%
#jb.loc['GoldenEye':'Moonracker',"Year":"Bond actor"]

# %% [markdown]
# ** to change the name of Sean Connery to Sir Sean Connery**

# %%
actor_Sean = jb["Bond actor"] == 'Sean Connery'
actor_Sean
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                              True
# For Your Eyes Only                 False
# From Russia With Love               True
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World is Not Enough            False
# Thunderball                         True
# Tomorrow Never Dies                False
# You Only Live Twice                 True
# ...

# %%
jb[actor_Sean]["Bond actor"] = 'Sir Sean Connery'
# Out:
# <ipython-input-244-9b36fb299ff2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jb[actor_Sean]["Bond actor"] = 'Sir Sean Connery'

# %%
jb.loc[actor_Sean,"Bond actor"] ='Sir Sean Connery'

# %%
jb.head(3)
# Out:
#                       Year  Years lapse        Bond actor  \
# Film
# A View to a Kill      1985          2.0       Roger Moore
# Casino Royale         2006          4.0      Daniel Craig
# Diamonds Are Forever  1971          2.0  Sir Sean Connery
#
#                       Bond actor appearance  Villians Dispatched  \
# Film
# A View to a Kill                          7                    5
# Casino Royale                             1                   11
# Diamonds Are Forever                      6                    7
#
#                       Others' Dispatched  Total Dispatched  \
# Film
# A View to a Kill                      57                62
# Casino Royale                         11                22
# Diamonds Are Forever                  42                49
#
#                       Adjusted box office  Actual box office  Adjusted budget  \
# Film
# A View to a Kill                    275.2              152.4             54.5
# ...

# %% [markdown]
# **Rename**
#
# >> mapper,axis \
# >>index,columns

# %%
jb.rename(columns = {"Year":"Release Year"})
# Out:
#                                  Release Year  Years lapse        Bond actor  \
# Film
# A View to a Kill                         1985          2.0       Roger Moore
# Casino Royale                            2006          4.0      Daniel Craig
# Diamonds Are Forever                     1971          2.0  Sir Sean Connery
# Die Another Day                          2002          3.0    Pierce Brosnan
# Dr. No                                   1962          NaN  Sir Sean Connery
# For Your Eyes Only                       1981          2.0       Roger Moore
# From Russia With Love                    1963          1.0  Sir Sean Connery
# GoldenEye                                1995          6.0    Pierce Brosnan
# Goldfinger                               1964          1.0  Sir Sean Connery
# Licence to Kill                          1989          2.0    Timothy Dalton
# Live and Let Die                         1973          2.0       Roger Moore
# ...

# %%
jb.rename(mapper = {"GoldenEye":"Golden Eye"},axis = 0)

#or

jb.rename(index ={"GoldenEye":"Golden Eye"}) # since this is index
# Out:
#                                  Year  Years lapse        Bond actor  \
# Film
# A View to a Kill                 1985          2.0       Roger Moore
# Casino Royale                    2006          4.0      Daniel Craig
# Diamonds Are Forever             1971          2.0  Sir Sean Connery
# Die Another Day                  2002          3.0    Pierce Brosnan
# Dr. No                           1962          NaN  Sir Sean Connery
# For Your Eyes Only               1981          2.0       Roger Moore
# From Russia With Love            1963          1.0  Sir Sean Connery
# Golden Eye                       1995          6.0    Pierce Brosnan
# Goldfinger                       1964          1.0  Sir Sean Connery
# Licence to Kill                  1989          2.0    Timothy Dalton
# Live and Let Die                 1973          2.0       Roger Moore
# Moonraker                        1979          2.0       Roger Moore
# ...

# %%
jb.pop('Total Dispatched')
# Out:
# Film
# A View to a Kill                    62
# Casino Royale                       22
# Diamonds Are Forever                49
# Die Another Day                     51
# Dr. No                              12
# For Your Eyes Only                  54
# From Russia With Love               27
# GoldenEye                           72
# Goldfinger                          77
# Licence to Kill                     23
# Live and Let Die                    13
# Moonraker                           81
# Octopussy                           58
# On Her Majesty's Secret Service     42
# Quantum of Solace                   31
# Skyfall                             49
# The Living Daylights                42
# The Man with the Golden Gun          6
# The Spy Who Loved Me               147
# The World is Not Enough             70
# Thunderball                        110
# Tomorrow Never Dies                 54
# You Only Live Twice                196
# Name: Total Dispatched, dtype: int64

# %%
jb.head()
# Out:
#                       Year  Years lapse        Bond actor  \
# Film
# A View to a Kill      1985          2.0       Roger Moore
# Casino Royale         2006          4.0      Daniel Craig
# Diamonds Are Forever  1971          2.0  Sir Sean Connery
# Die Another Day       2002          3.0    Pierce Brosnan
# Dr. No                1962          NaN  Sir Sean Connery
#
#                       Bond actor appearance  Villians Dispatched  \
# Film
# A View to a Kill                          7                    5
# Casino Royale                             1                   11
# Diamonds Are Forever                      6                    7
# Die Another Day                           4                   31
# Dr. No                                    1                    4
#
#                       Others' Dispatched  Adjusted box office  \
# Film
# A View to a Kill                      57                275.2
# Casino Royale                         11                581.5
# ...

# %% [markdown]
# # Random

# %%
#random row

jb.sample()
jb.sample(n=2)
# Out:
#                  Year  Years lapse      Bond actor  Bond actor appearance  \
# Film
# Casino Royale    2006          4.0    Daniel Craig                      1
# Licence to Kill  1989          2.0  Timothy Dalton                      2
#
#                  Villians Dispatched  Others' Dispatched  Adjusted box office  \
# Film
# Casino Royale                     11                  11                581.5
# Licence to Kill                   10                  13                250.9
#
#                  Actual box office  Adjusted budget  Actual budget  ...  \
# Film                                                                ...
# Casino Royale                594.2            145.3          150.0  ...
# Licence to Kill              156.2             56.7           36.0  ...
#
#                 Golden Globe wins Academy Award nominations  \
# Film
# Casino Royale                   0                         0
# Licence to Kill                 0                         0
#
# ...

# %%
# random columns

jb.sample(n = 2 , axis = 1) # axis = 'columns'
# Out:
#                                 Rotten Tomatoes critic score  Year
# Film
# A View to a Kill                                         34%  1985
# Casino Royale                                            95%  2006
# Diamonds Are Forever                                     66%  1971
# Die Another Day                                          57%  2002
# Dr. No                                                   96%  1962
# For Your Eyes Only                                       73%  1981
# From Russia With Love                                    96%  1963
# GoldenEye                                                82%  1995
# Goldfinger                                               96%  1964
# Licence to Kill                                          76%  1989
# Live and Let Die                                         66%  1973
# Moonraker                                                59%  1979
# Octopussy                                                43%  1983
# ...

# %% [markdown]
# **nlargest , nsmallest **

# %%
jb.nlargest(n=3,columns = "Actual box office")
# Out:
#                    Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Skyfall            2012          4.0  Daniel Craig                      3
# Casino Royale      2006          4.0  Daniel Craig                      1
# Quantum of Solace  2008          2.0  Daniel Craig                      2
#
#                    Villians Dispatched  Others' Dispatched  \
# Film
# Skyfall                             26                  23
# Casino Royale                       11                  11
# Quantum of Solace                   16                  15
#
#                    Adjusted box office  Actual box office  Adjusted budget  \
# Film
# Skyfall                          879.8             1108.6            158.1
# Casino Royale                    581.5              594.2            145.3
# Quantum of Solace                514.2              576.0            181.4
#
#                    Actual budget  ... Golden Globe wins  \
# Film                              ...
# ...

# %%
jb["Actual box office"].nlargest(n=3)

# OR

jb.nlargest(n=3,columns = "Actual box office")
# Out:
#                    Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Skyfall            2012          4.0  Daniel Craig                      3
# Casino Royale      2006          4.0  Daniel Craig                      1
# Quantum of Solace  2008          2.0  Daniel Craig                      2
#
#                    Villians Dispatched  Others' Dispatched  \
# Film
# Skyfall                             26                  23
# Casino Royale                       11                  11
# Quantum of Solace                   16                  15
#
#                    Adjusted box office  Actual box office  Adjusted budget  \
# Film
# Skyfall                          879.8             1108.6            158.1
# Casino Royale                    581.5              594.2            145.3
# Quantum of Solace                514.2              576.0            181.4
#
#                    Actual budget  ... Golden Globe wins  \
# Film                              ...
# ...

# %% [markdown]
# # Working With Text Data

# %%
cd = pd.read_csv(r"C:\Users\RAHUL RAJ\Desktop\ML_Practise\chicago.csv").dropna(how = 'all')
cd.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
cd.nunique()
# Out:
# Name                      31776
# Position Title             1093
# Department                   35
# Employee Annual Salary     1156
# dtype: int64

# %%
cd['Department'] = cd['Department'].astype("category")

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %% [markdown]
# **lower(), upper(), title()**
# >whenever we work on Series we prefix them with str.
# .str.lower()

# %%
cd["Name"] = cd["Name"].str.title()
cd["Position Title"] = cd["Position Title"].str.title()

# %%
cd["Department"] = cd["Department"].str.title()

# %%
cd.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          Water Rate Taker       Water Mgmnt
# 1    Aaron,  Jeffery M            Police Officer            Police
# 2       Aaron,  Karina            Police Officer            Police
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  General Services
# 4  Abad Jr,  Vicente M         Civil Engineer Iv       Water Mgmnt
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %% [markdown]
# **str.replace(old,new)**

# %%
cd["Department"] = cd["Department"].str.replace("Mgmnt","Management")

# %%
cd.head(3)
# Out:
#                 Name    Position Title        Department  \
# 0    Aaron,  Elvia J  Water Rate Taker  Water Management
# 1  Aaron,  Jeffery M    Police Officer            Police
# 2     Aaron,  Karina    Police Officer            Police
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00

# %% [markdown]
# **.str.contains(), .str.startswith() , .str.endswith()**

# %%
wat = cd['Position Title'].str.lower().str.contains('water')

# wat = cd['Position Title'].str.lower().str.startswith('water')

# %%
cd[wat]
# Out:
#                        Name                                 Position Title  \
# 0           Aaron,  Elvia J                               Water Rate Taker
# 554      Aluise,  Vincent G             Foreman Of Water Pipe Construction
# 671         Ander,  Perry A                               Water Chemist Ii
# 685     Anderson,  Andrew J  District Superintendent Of Water Distribution
# 702       Anderson,  Donald             Foreman Of Water Pipe Construction
# ...                     ...                                            ...
# 29669        Verma,  Anupam           Managing Engineer - Water Management
# 30239   Washington,  Joseph                              Water Chemist Iii
# 30544       West,  Thomas R                   Gen Supt Of Water Management
# 30991    Williams,  Matthew             Foreman Of Water Pipe Construction
# 31405  Woodridge,  Robert L             Foreman Of Water Pipe Construction
#
#              Department Employee Annual Salary
# ...

# %% [markdown]
# wherever 'water' was found in 'Position Title' alone is returned

# %%
ew = cd['Position Title'].str.lower().str.endswith('ist')
cd[ew]
# Out:
#                           Name                        Position Title  \
# 184             Afroz,  Nayyar                          Psychiatrist
# 308           Alarcon,  Luis J            Loan Processing Specialist
# 422           Allain,  Carolyn  Senior Telecommunications Specialist
# 472             Allen,  Robert                             Machinist
# 705        Anderson,  Edward M             Sr Procurement Specialist
# ...                        ...                                   ...
# 31667         Yoder,  Teresa G                   Archival Specialist
# 31688  Youngbloom,  Laurence G        Crimes Surveillance Specialist
# 31717       Young,  Kimberly M             Sr Procurement Specialist
# 31837            Zapata,  Hugo             Sr Procurement Specialist
# 31918        Zemke,  Richard P                             Machinist
#
#                   Department Employee Annual Salary
# 184                   Health              $99840.00
# ...

# %% [markdown]
# wherever 'ist' is ended in 'Position Title' alone is returned

# %% [markdown]
# **strip(), lstrip(), rstrip()**
# >removes from all sides, left side, right side

# %%
cd['Name'] = cd['Name'].str.lstrip().str.rstrip()

# %%
cd['Position Title'] = cd['Position Title'].str.strip()

# %%
cd.set_index('Name') #str.strip()
# Out:
#                                      Position Title        Department  \
# Name
# Aaron,  Elvia J                    Water Rate Taker  Water Management
# Aaron,  Jeffery M                    Police Officer            Police
# Aaron,  Karina                       Police Officer            Police
# Aaron,  Kimberlei R        Chief Contract Expediter  General Services
# Abad Jr,  Vicente M               Civil Engineer Iv  Water Management
# ...                                             ...               ...
# Zygadlo,  Michael J  Frm Of Machinists - Automotive  General Services
# Zygowicz,  Peter J                   Police Officer            Police
# Zymantas,  Mark E                    Police Officer            Police
# Zyrkowski,  Carlo E                  Police Officer            Police
# Zyskowski,  Dariusz         Chief Data Base Analyst              Doit
#
#                     Employee Annual Salary
# Name
# Aaron,  Elvia J                  $90744.00
# ...

# %% [markdown]
# **str.split()**
# &
# str.get(indx)

# %%
cd['First_Name'] = cd['Name'].str.split(',').str.get(0)

# %%
cd['Last_Name'] = cd['Name'].str.split(',').str.get(1)

# %%
cd.head(3)
# Out:
#                 Name    Position Title        Department  \
# 0    Aaron,  Elvia J  Water Rate Taker  Water Management
# 1  Aaron,  Jeffery M    Police Officer            Police
# 2     Aaron,  Karina    Police Officer            Police
#
#   Employee Annual Salary First_Name    Last_Name
# 0              $90744.00      Aaron      Elvia J
# 1              $84450.00      Aaron    Jeffery M
# 2              $84450.00      Aaron       Karina

# %%
cd['Last_Name'].str.split('1')
# Out:
# 0            [  Elvia J]
# 1          [  Jeffery M]
# 2             [  Karina]
# 3        [  Kimberlei R]
# 4          [  Vicente M]
#               ...
# 32057      [  Michael J]
# 32058        [  Peter J]
# 32059         [  Mark E]
# 32060        [  Carlo E]
# 32061        [  Dariusz]
# Name: Last_Name, Length: 32062, dtype: object

# %% [markdown]
# to remove spaces strip()

# %%
cd['Initial'] = cd['Last_Name'].str.strip().str.split().str.get(1)

# %%
cd.head(3)
# Out:
#                 Name    Position Title        Department  \
# 0    Aaron,  Elvia J  Water Rate Taker  Water Management
# 1  Aaron,  Jeffery M    Police Officer            Police
# 2     Aaron,  Karina    Police Officer            Police
#
#   Employee Annual Salary First_Name    Last_Name Initial
# 0              $90744.00      Aaron      Elvia J       J
# 1              $84450.00      Aaron    Jeffery M       M
# 2              $84450.00      Aaron       Karina     NaN

# %%
cd['Name'].str.split(',',expand=True) # n = maxium no.of splits )
# Out:
#                0              1
# 0          Aaron        Elvia J
# 1          Aaron      Jeffery M
# 2          Aaron         Karina
# 3          Aaron    Kimberlei R
# 4        Abad Jr      Vicente M
# ...          ...            ...
# 32057    Zygadlo      Michael J
# 32058   Zygowicz        Peter J
# 32059   Zymantas         Mark E
# 32060  Zyrkowski        Carlo E
# 32061  Zyskowski        Dariusz
#
# [32062 rows x 2 columns]

# %% [markdown]
# returns as a Dataframe

# %%
bd = pd.read_csv(r"C:\Users\RAHUL RAJ\Desktop\ML_Practise\bigmac.csv")
bd.head(3)
# Out:
#          date currency_code       name  local_price  dollar_ex  dollar_price
# 0  2000-04-01           ARS  Argentina         2.50       1.00      2.500000
# 1  2000-04-01           AUD  Australia         2.59       1.68      1.541667
# 2  2000-04-01           BRL     Brazil         2.95       1.79      1.648045

# %%
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1330 non-null   object
#  1   currency_code  1330 non-null   object
#  2   name           1330 non-null   object
#  3   local_price    1330 non-null   float64
#  4   dollar_ex      1330 non-null   float64
#  5   dollar_price   1330 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 62.5+ KB

# %%
bd['date'] = pd.to_datetime(bd['date'])

# %%
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1330 non-null   datetime64[ns]
#  1   currency_code  1330 non-null   object
#  2   name           1330 non-null   object
#  3   local_price    1330 non-null   float64
#  4   dollar_ex      1330 non-null   float64
#  5   dollar_price   1330 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 62.5+ KB

# %%
bd.head(2)
# Out:
#         date currency_code       name  local_price  dollar_ex  dollar_price
# 0 2000-04-01           ARS  Argentina         2.50       1.00      2.500000
# 1 2000-04-01           AUD  Australia         2.59       1.68      1.541667

# %%
bd.rename(columns={"name":"country"},inplace = True)

# %%
bd.head(2)
# Out:
#         date currency_code    country  local_price  dollar_ex  dollar_price
# 0 2000-04-01           ARS  Argentina         2.50       1.00      2.500000
# 1 2000-04-01           AUD  Australia         2.59       1.68      1.541667

# %%
bd.set_index(keys = ['date','country'],inplace = True)

# %%
bd.head()
# Out:
#                        currency_code  local_price  dollar_ex  dollar_price
# date       country
# 2000-04-01 Argentina             ARS         2.50       1.00      2.500000
#            Australia             AUD         2.59       1.68      1.541667
#            Brazil                BRL         2.95       1.79      1.648045
#            Canada                CAD         2.85       1.47      1.938776
#            Switzerland           CHF         5.90       1.70      3.470588

# %% [markdown]
# # outermost level is column with most unique values

# %%
bd.sort_index()
# Out:
#                                 currency_code  local_price     dollar_ex  \
# date       country
# 2000-04-01 Argentina                      ARS         2.50      1.000000
#            Australia                      AUD         2.59      1.680000
#            Brazil                         BRL         2.95      1.790000
#            Britain                        GBP         1.90      0.632911
#            Canada                         CAD         2.85      1.470000
# ...                                       ...          ...           ...
# 2020-01-14 Ukraine                        UAH        57.00     23.990000
#            United Arab Emirates           AED        14.75      3.673150
#            United States                  USD         5.67      1.000000
#            Uruguay                        UYU       179.00     37.435000
#            Vietnam                        VND     66000.00  23176.000000
#
#                                  dollar_price
# date       country
# ...

# %%
bd.index
# Out:
# MultiIndex([('2000-04-01',      'Argentina'),
#             ('2000-04-01',      'Australia'),
#             ('2000-04-01',         'Brazil'),
#             ('2000-04-01',         'Canada'),
#             ('2000-04-01',    'Switzerland'),
#             ('2000-04-01',          'Chile'),
#             ('2000-04-01',          'China'),
#             ('2000-04-01', 'Czech Republic'),
#             ('2000-04-01',        'Denmark'),
#             ('2000-04-01',      'Euro area'),
#             ...
#             ('2020-01-14',      'Singapore'),
#             ('2020-01-14',         'Sweden'),
#             ('2020-01-14',       'Thailand'),
#             ('2020-01-14',         'Turkey'),
#             ('2020-01-14',         'Taiwan'),
#             ('2020-01-14',        'Ukraine'),
#             ('2020-01-14',        'Uruguay'),
#             ('2020-01-14',  'United States'),
#             ('2020-01-14',        'Vietnam'),
#             ('2020-01-14',   'South Africa')],
# ...

# %%
bd.index[0]
# Out:
# (Timestamp('2000-04-01 00:00:00'), 'Argentina')

# %% [markdown]
# **.index.get_level_values**

# %%
bd.index.get_level_values('date')             # if str then we could have used str.get(0) but it is a tuple

#or

# bd.index.get_level_values(0)
# Out:
# DatetimeIndex(['2000-04-01', '2000-04-01', '2000-04-01', '2000-04-01',
#                '2000-04-01', '2000-04-01', '2000-04-01', '2000-04-01',
#                '2000-04-01', '2000-04-01',
#                ...
#                '2020-01-14', '2020-01-14', '2020-01-14', '2020-01-14',
#                '2020-01-14', '2020-01-14', '2020-01-14', '2020-01-14',
#                '2020-01-14', '2020-01-14'],
#               dtype='datetime64[ns]', name='date', length=1330, freq=None)

# %%
bd.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Canada', 'Switzerland', 'Chile',
#        'China', 'Czech Republic', 'Denmark', 'Euro area',
#        ...
#        'Singapore', 'Sweden', 'Thailand', 'Turkey', 'Taiwan', 'Ukraine',
#        'Uruguay', 'United States', 'Vietnam', 'South Africa'],
#       dtype='object', name='country', length=1330)

# %%
bd.sort_index(ascending = [True,False])

#or

# bd.sort_index(level = 0)   sorts the level 0 date in ascending,undistrubes country
# Out:
#                          currency_code  local_price  dollar_ex  dollar_price
# date       country
# 2000-04-01 United States           USD         2.51   1.000000      2.510000
#            Thailand                THB        55.00  38.000000      1.447368
#            Taiwan                  TWD        70.00  30.600000      2.287582
#            Switzerland             CHF         5.90   1.700000      3.470588
#            Sweden                  SEK        24.00   8.840000      2.714932
# ...                                ...          ...        ...           ...
# 2020-01-14 Brazil                  BRL        19.90   4.141900      4.804558
#            Bahrain                 BHD         1.40   0.377000      3.713528
#            Azerbaijan              AZN         3.95   1.696500      2.328323
#            Australia               AUD         6.45   1.449065      4.451145
#            Argentina               ARS       171.00  60.065600      2.846887
#
# [1330 rows x 4 columns]

# %% [markdown]
# **loc in Multiindex**

# %%
# pd.loc[rows,columns]
  
# pd.loc[(tuples),column]

bd.loc[('2000-04-01','Sweden'),'dollar_price']
# Out:
# date        country
# 2000-04-01  Sweden     2.714932
# Name: dollar_price, dtype: float64

# %%
bd.loc[('2000-04-01','Brazil')]
# Out:
# currency_code        BRL
# local_price         2.95
# dollar_ex           1.79
# dollar_price     1.64804
# Name: (2000-04-01 00:00:00, Brazil), dtype: object

# %%
bd.loc[('2000-04-01',)]  # displays all values of that index other than itself
# Out:
#                currency_code  local_price    dollar_ex  dollar_price
# country
# Argentina                ARS         2.50     1.000000      2.500000
# Australia                AUD         2.59     1.680000      1.541667
# Brazil                   BRL         2.95     1.790000      1.648045
# Canada                   CAD         2.85     1.470000      1.938776
# Switzerland              CHF         5.90     1.700000      3.470588
# Chile                    CLP      1260.00   514.000000      2.451362
# China                    CNY         9.90     8.280000      1.195652
# Czech Republic           CZK        54.37    39.100000      1.390537
# Denmark                  DKK        24.75     8.040000      3.078358
# Euro area                EUR         2.56     1.075269      2.380800
# Britain                  GBP         1.90     0.632911      3.002000
# Hong Kong                HKD        10.20     7.790000      1.309371
# ...

# %% [markdown]
# **iloc in multiindex**

# %%
bd.iloc[0]
# Out:
# currency_code    ARS
# local_price      2.5
# dollar_ex          1
# dollar_price     2.5
# Name: (2000-04-01 00:00:00, Argentina), dtype: object

# %%
bd.iloc[[10,12]]
# Out:
#                    currency_code  local_price   dollar_ex  dollar_price
# date       country
# 2000-04-01 Britain           GBP          1.9    0.632911      3.002000
#            Hungary           HUF        339.0  279.000000      1.215054

# %%
bd.transpose()
# Out:
# date          2000-04-01                                                   \
# country        Argentina Australia   Brazil   Canada Switzerland    Chile
# currency_code        ARS       AUD      BRL      CAD         CHF      CLP
# local_price          2.5      2.59     2.95     2.85         5.9     1260
# dollar_ex              1      1.68     1.79     1.47         1.7      514
# dollar_price         2.5   1.54167  1.64804  1.93878     3.47059  2.45136
#
# date                                                      ... 2020-01-14  \
# country          China Czech Republic  Denmark Euro area  ...  Singapore
# currency_code      CNY            CZK      DKK       EUR  ...        SGD
# local_price        9.9          54.37    24.75      2.56  ...        5.9
# dollar_ex         8.28           39.1     8.04   1.07527  ...    1.34715
# dollar_price   1.19565        1.39054  3.07836    2.3808  ...    4.37962
#
# date                                                                 \
# ...

# %%
bd.swaplevel()

bd.swaplevel('date','country')
bd.swaplevel(0,1)
# Out:
#                          currency_code  local_price  dollar_ex  dollar_price
# country       date
# Argentina     2000-04-01           ARS         2.50      1.000      2.500000
# Australia     2000-04-01           AUD         2.59      1.680      1.541667
# Brazil        2000-04-01           BRL         2.95      1.790      1.648045
# Canada        2000-04-01           CAD         2.85      1.470      1.938776
# Switzerland   2000-04-01           CHF         5.90      1.700      3.470588
# ...                                ...          ...        ...           ...
# Ukraine       2020-01-14           UAH        57.00     23.990      2.375990
# Uruguay       2020-01-14           UYU       179.00     37.435      4.781621
# United States 2020-01-14           USD         5.67      1.000      5.670000
# Vietnam       2020-01-14           VND     66000.00  23176.000      2.847774
# South Africa  2020-01-14           ZAR        31.00     14.391      2.154124
#
# [1330 rows x 4 columns]

# %%
bd.stack()
# Out:
# date        country
# 2000-04-01  Argentina     currency_code        ARS
#                           local_price          2.5
#                           dollar_ex              1
#                           dollar_price         2.5
#             Australia     currency_code        AUD
#                                             ...
# 2020-01-14  Vietnam       dollar_price     2.84777
#             South Africa  currency_code        ZAR
#                           local_price           31
#                           dollar_ex         14.391
#                           dollar_price     2.15412
# Length: 5320, dtype: object

# %%
bd.stack().shape  # 1D a pandas sereis object
# Out:
# (5320,)

# %%
bd.stack().to_frame()
# Out:
#                                              0
# date       country
# 2000-04-01 Argentina    currency_code      ARS
#                         local_price        2.5
#                         dollar_ex            1
#                         dollar_price       2.5
#            Australia    currency_code      AUD
# ...                                        ...
# 2020-01-14 Vietnam      dollar_price   2.84777
#            South Africa currency_code      ZAR
#                         local_price         31
#                         dollar_ex       14.391
#                         dollar_price   2.15412
#
# [5320 rows x 1 columns]

# %%
bd.stack().to_frame().shape
# Out:
# (5320, 1)

# %%
bd.stack().unstack().unstack()
# Out:
#            currency_code                                                     \
# country        Argentina Australia Azerbaijan Bahrain Brazil Britain Canada
# date
# 2000-04-01           ARS       AUD        NaN     NaN    BRL     GBP    CAD
# 2001-04-01           ARS       AUD        NaN     NaN    BRL     GBP    CAD
# 2002-04-01           ARS       AUD        NaN     NaN    BRL     GBP    CAD
# 2003-04-01           ARS       AUD        NaN     NaN    BRL     GBP    CAD
# 2004-05-01           ARS       AUD        NaN     NaN    BRL     GBP    CAD
# 2005-06-01           ARS       AUD        NaN     NaN    BRL     GBP    CAD
# 2006-01-01           ARS       AUD        NaN     NaN    BRL     GBP    CAD
# 2006-05-01           ARS       AUD        NaN     NaN    BRL     GBP    CAD
# 2007-01-01           ARS       AUD        NaN     NaN    BRL     GBP    CAD
# 2007-06-01           ARS       AUD        NaN     NaN    BRL     GBP    CAD
# ...

# %%
bd.stack().unstack().unstack().unstack()
# Out:
#                country    date
# currency_code  Argentina  2000-04-01        ARS
#                           2001-04-01        ARS
#                           2002-04-01        ARS
#                           2003-04-01        ARS
#                           2004-05-01        ARS
#                                          ...
# dollar_price   Vietnam    2018-01-01    2.86199
#                           2018-07-01    2.82124
#                           2019-01-01    2.80184
#                           2019-07-09    2.79799
#                           2020-01-14    2.84777
# Length: 7296, dtype: object

# %%
s = bd.stack()
s
# Out:
# date        country
# 2000-04-01  Argentina     currency_code        ARS
#                           local_price          2.5
#                           dollar_ex              1
#                           dollar_price         2.5
#             Australia     currency_code        AUD
#                                             ...
# 2020-01-14  Vietnam       dollar_price     2.84777
#             South Africa  currency_code        ZAR
#                           local_price           31
#                           dollar_ex         14.391
#                           dollar_price     2.15412
# Length: 5320, dtype: object

# %%
s.unstack(1)
# Out:
# country                  Argentina Australia Azerbaijan  Bahrain   Brazil  \
# date
# 2000-04-01 currency_code       ARS       AUD        NaN      NaN      BRL
#            local_price         2.5      2.59        NaN      NaN     2.95
#            dollar_ex             1      1.68        NaN      NaN     1.79
#            dollar_price        2.5   1.54167        NaN      NaN  1.64804
# 2001-04-01 currency_code       ARS       AUD        NaN      NaN      BRL
# ...                            ...       ...        ...      ...      ...
# 2019-07-09 dollar_price     2.8705   4.26011    2.32832  3.71353  4.59643
# 2020-01-14 currency_code       ARS       AUD        AZN      BHD      BRL
#            local_price         171      6.45       3.95      1.4     19.9
#            dollar_ex       60.0656   1.44907     1.6965    0.377   4.1419
#            dollar_price    2.84689   4.45115    2.32832  3.71353  4.80456
#
# ...

# %%
s.unstack([1,0])  #,fill_values = value
# Out:
# country        Argentina  Australia     Brazil     Canada Switzerland  \
# date          2000-04-01 2000-04-01 2000-04-01 2000-04-01  2000-04-01
# currency_code        ARS        AUD        BRL        CAD         CHF
# local_price          2.5       2.59       2.95       2.85         5.9
# dollar_ex              1       1.68       1.79       1.47         1.7
# dollar_price         2.5    1.54167    1.64804    1.93878     3.47059
#
# country            Chile      China Czech Republic    Denmark  Euro area  ...  \
# date          2000-04-01 2000-04-01     2000-04-01 2000-04-01 2000-04-01  ...
# currency_code        CLP        CNY            CZK        DKK        EUR  ...
# local_price         1260        9.9          54.37      24.75       2.56  ...
# dollar_ex            514       8.28           39.1       8.04    1.07527  ...
# dollar_price     2.45136    1.19565        1.39054    3.07836     2.3808  ...
#
# country        Singapore     Sweden   Thailand     Turkey     Taiwan  \
# ...

# %% [markdown]
# # pivot_table

# %%
jb.head()
# Out:
#                       Year  Years lapse        Bond actor  \
# Film
# A View to a Kill      1985          2.0       Roger Moore
# Casino Royale         2006          4.0      Daniel Craig
# Diamonds Are Forever  1971          2.0  Sir Sean Connery
# Die Another Day       2002          3.0    Pierce Brosnan
# Dr. No                1962          NaN  Sir Sean Connery
#
#                       Bond actor appearance  Villians Dispatched  \
# Film
# A View to a Kill                          7                    5
# Casino Royale                             1                   11
# Diamonds Are Forever                      6                    7
# Die Another Day                           4                   31
# Dr. No                                    1                    4
#
#                       Others' Dispatched  Adjusted box office  \
# Film
# A View to a Kill                      57                275.2
# Casino Royale                         11                581.5
# ...

# %%
jb.pivot_table(index ="Film",columns ='Bond actor',values = 'Villians Dispatched',fill_value = '-').head(5)
# Out:
# Bond actor           Daniel Craig George Lazenby Pierce Brosnan Roger Moore  \
# Film
# A View to a Kill                -              -              -           5
# Casino Royale                  11              -              -           -
# Diamonds Are Forever            -              -              -           -
# Die Another Day                 -              -             31           -
# Dr. No                          -              -              -           -
#
# Bond actor           Sir Sean Connery Timothy Dalton
# Film
# A View to a Kill                    -              -
# Casino Royale                       -              -
# Diamonds Are Forever                7              -
# Die Another Day                     -              -
# Dr. No                              4              -

# %%
jb.pivot_table(index ="Bond actor",values = ['Villians Dispatched', 'Bond girls'],aggfunc = 'sum' )
# Out:
#                   Bond girls  Villians Dispatched
# Bond actor
# Daniel Craig               6                   53
# George Lazenby             3                    5
# Pierce Brosnan            12                  135
# Roger Moore               24                   90
# Sir Sean Connery          25                   72
# Timothy Dalton             4                   23

# %% [markdown]
# **df.groupby()**

# %%
jb.groupby('Bond actor')

# %%
bondactr = jb.groupby('Bond actor')

# %%
len(bondactr)  # 6 different groups
# Out:
# 6

# %%
bondactr.size()
# Out:
# Bond actor
# Daniel Craig        3
# George Lazenby      1
# Pierce Brosnan      4
# Roger Moore         7
# Sir Sean Connery    6
# Timothy Dalton      2
# dtype: int64

# %%
bondactr.first()   # first value in the grouping 
# bondactr.last()   # last value in the grouping
# Out:
#                   Year  Years lapse  Bond actor appearance  \
# Bond actor
# Daniel Craig      2006          4.0                      1
# George Lazenby    1969          2.0                      1
# Pierce Brosnan    2002          3.0                      4
# Roger Moore       1985          2.0                      7
# Sir Sean Connery  1971          2.0                      6
# Timothy Dalton    1989          2.0                      2
#
#                   Villians Dispatched  Others' Dispatched  \
# Bond actor
# Daniel Craig                       11                  11
# George Lazenby                      5                  37
# Pierce Brosnan                     31                  20
# Roger Moore                         5                  57
# Sir Sean Connery                    7                  42
# Timothy Dalton                     10                  13
#
#                   Adjusted box office  Actual box office  Adjusted budget  \
# Bond actor
# ...

# %%
bondactr.groups # as a dictionary of key = groupby columna and others as index values
# Out:
# {'Daniel Craig': Index(['Casino Royale', 'Quantum of Solace', 'Skyfall'], dtype='object', name='Film'),
#  'George Lazenby': Index(['On Her Majesty's Secret Service'], dtype='object', name='Film'),
#  'Pierce Brosnan': Index(['Die Another Day', 'GoldenEye', 'The World is Not Enough',
#         'Tomorrow Never Dies'],
#        dtype='object', name='Film'),
#  'Roger Moore': Index(['A View to a Kill', 'For Your Eyes Only', 'Live and Let Die',
#         'Moonraker', 'Octopussy', 'The Man with the Golden Gun',
#         'The Spy Who Loved Me'],
#        dtype='object', name='Film'),
#  'Sir Sean Connery': Index(['Diamonds Are Forever', 'Dr. No', 'From Russia With Love', 'Goldfinger',
#         'Thunderball', 'You Only Live Twice'],
#        dtype='object', name='Film'),
#  'Timothy Dalton': Index(['Licence to Kill', 'The Living Daylights'], dtype='object', name='Film')}

# %%
bondactr.get_group('Sir Sean Connery')
# Out:
#                        Year  Years lapse  Bond actor appearance  \
# Film
# Diamonds Are Forever   1971          2.0                      6
# Dr. No                 1962          NaN                      1
# From Russia With Love  1963          1.0                      2
# Goldfinger             1964          1.0                      3
# Thunderball            1965          1.0                      4
# You Only Live Twice    1967          2.0                      5
#
#                        Villians Dispatched  Others' Dispatched  \
# Film
# Diamonds Are Forever                     7                  42
# Dr. No                                   4                   8
# From Russia With Love                   11                  16
# Goldfinger                               9                  68
# Thunderball                             20                  90
# You Only Live Twice                     21                 175
#
# ...

# %%
bondactr.sum() # aggregates everything
# Out:
#                    Year  Years lapse  Bond actor appearance  \
# Bond actor
# Daniel Craig       6026         10.0                      6
# George Lazenby     1969          2.0                      1
# Pierce Brosnan     7993         13.0                     10
# Roger Moore       13852         14.0                     28
# Sir Sean Connery  11792          7.0                     21
# Timothy Dalton     3976          4.0                      3
#
#                   Villians Dispatched  Others' Dispatched  \
# Bond actor
# Daniel Craig                       53                  49
# George Lazenby                      5                  37
# Pierce Brosnan                    135                 112
# Roger Moore                        90                 331
# Sir Sean Connery                   72                 399
# Timothy Dalton                     23                  42
#
#                   Adjusted box office  Actual box office  Adjusted budget  \
# Bond actor
# ...

# %%
bondactr['Adjusted box office'].sum()
# Out:
# Bond actor
# Daniel Craig        1975.5
# George Lazenby       291.5
# Pierce Brosnan      1886.6
# Roger Moore         2960.7
# Sir Sean Connery    3617.8
# Timothy Dalton       564.4
# Name: Adjusted box office, dtype: float64

# %%
bondactr['Bond girls'].sum()
# Out:
# Bond actor
# Daniel Craig         6
# George Lazenby       3
# Pierce Brosnan      12
# Roger Moore         24
# Sir Sean Connery    25
# Timothy Dalton       4
# Name: Bond girls, dtype: int64

# %%
bd.head()
# Out:
#                        currency_code  local_price  dollar_ex  dollar_price
# date       country
# 2000-04-01 Argentina             ARS         2.50       1.00      2.500000
#            Australia             AUD         2.59       1.68      1.541667
#            Brazil                BRL         2.95       1.79      1.648045
#            Canada                CAD         2.85       1.47      1.938776
#            Switzerland           CHF         5.90       1.70      3.470588

# %%
dcg = bd.groupby(['currency_code','country'])

# %%
dcg.size().head(5)
# Out:
# currency_code  country
# AED            UAE                     22
#                United Arab Emirates     4
# ARS            Argentina               32
# AUD            Australia               32
# AZN            Azerbaijan               4
# dtype: int64

# %%
dcg.agg({'local_price':'mean',
         'dollar_price':'sum'},).head(5)
# Out:
#                                     local_price  dollar_price
# currency_code country
# AED           UAE                     11.727273     70.243265
#               United Arab Emirates    14.375000     15.654139
# ARS           Argentina               31.670625     92.556207
# AUD           Australia                4.555781    117.151605
# AZN           Azerbaijan               3.950000      9.306109

# %%
dfbd = pd.DataFrame(columns = bd.columns)
dfbd
# Out:
# Empty DataFrame
# Columns: [currency_code, local_price, dollar_ex, dollar_price]
# Index: []

# %%
for g,d in dcg:
    high_price_in_group = d.nlargest(1,'dollar_price')
    dfbd = dfbd.append(high_price_in_group)

# %%
dfbd
# Out:
#                                             currency_code  local_price  \
# (2017-07-01 00:00:00, UAE)                            AED     14.00000
# (2019-07-09 00:00:00, United Arab Emirates)           AED     14.75000
# (2011-07-01 00:00:00, Argentina)                      ARS     20.00000
# (2011-07-01 00:00:00, Australia)                      AUD      4.56000
# (2019-01-01 00:00:00, Azerbaijan)                     AZN      3.95000
# (2019-07-09 00:00:00, Bahrain)                        BHD      1.40000
# (2011-07-01 00:00:00, Brazil)                         BRL      9.50000
# (2013-01-01 00:00:00, Canada)                         CAD      5.41000
# (2011-07-01 00:00:00, Switzerland)                    CHF      6.50000
# (2013-01-01 00:00:00, Chile)                          CLP   2050.00000
# (2018-01-01 00:00:00, China)                          CNY     20.40000
# (2013-01-01 00:00:00, Colombia)                       COP   8600.00000
# ...

# %% [markdown]
# # Merging joining Concatenating df

# %%
w1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
w2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
cust = pd.read_csv("Restaurant - Customers.csv")
fd = pd.read_csv('Restaurant - Foods.csv')

# %%
w1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
w2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
cust.head(2)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer

# %%
fd.head(2)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99

# %% [markdown]
# 1. append()

# %%
w1.append(other = w2) #ignore_index=False when True it indexes all togther from 0-500 else 0-251,0-249
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %% [markdown]
# 2.concate()

# %%
sal = pd.concat(objs = [w1,w2],keys=['Week1','Week2'])   # Multiindex
sal.head(5)
# Out:
#          Customer ID  Food ID
# Week1 0          537        9
#       1           97        4
#       2          658        1
#       3          202        2
#       4          155        9

# %%
sal.loc[['Week2',]]
# Out:
#            Customer ID  Food ID
# Week2 0            688       10
#       1            813        7
#       2            495       10
#       3            189        5
#       4            267        3
# ...                ...      ...
#       245          783       10
#       246          556       10
#       247          547        9
#       248          252        9
#       249          249        6
#
# [250 rows x 2 columns]

# %%
sal.loc['Week2',245]
# Out:
# Customer ID    783
# Food ID         10
# Name: (Week2, 245), dtype: int64

# %%
sal.loc[('Week1',0),"Customer ID"]
# Out:
# 537

# %% [markdown]
# # Merge - left,right,inner,outer join

# %% [markdown]
# df1.merge(d2,how ='jointype', on = 'key',suffixes = ['newname1','newname2'])

# %%
w1.merge(right = w2, how ='inner' , on ='Customer ID',suffixes = ['-W1','-W2'] ).head(5)
# Out:
#    Customer ID  Food ID-W1  Food ID-W2
# 0          537           9           5
# 1          155           9           3
# 2          155           1           3
# 3          503           5           8
# 4          503           5           9

# %% [markdown]
# **In week 1 ,customer came and bought Food ID 9 & 1**

# %%
w1[w1['Customer ID'] == 155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %% [markdown]
# **In week 2 ,customer came and bought Food ID 3**

# %%
w2[w2['Customer ID'] == 155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %% [markdown]
# **Inner Join** so all the values for Customer ID 155 will be returned

# %%
w1.merge(right = w2, how ='inner' , on =['Customer ID','Food ID'])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %% [markdown]
# These are the customer who came on week 1 and week 2 and ordered same food.
#
# **Customer 21 and 578 had  come twice in a week and ordered so we see them again**

# %%
w1.merge(right = w2, how ='outer' , on ='Customer ID',indicator = True)
# Out:
#      Customer ID  Food ID_x  Food ID_y      _merge
# 0            537        9.0        5.0        both
# 1             97        4.0        NaN   left_only
# 2            658        1.0        NaN   left_only
# 3            202        2.0        NaN   left_only
# 4            155        9.0        3.0        both
# ..           ...        ...        ...         ...
# 449          855        NaN        4.0  right_only
# 450          559        NaN       10.0  right_only
# 451          276        NaN        4.0  right_only
# 452          556        NaN       10.0  right_only
# 453          252        NaN        9.0  right_only
#
# [454 rows x 4 columns]

# %%
len(w1.merge(right = w2, how ='outer' , on ='Customer ID'))
# Out:
# 454

# %%
500 - 454 # Customer Id's are both in week1  and Week2
# Out:
# 46

# %%
om = w1.merge(right = w2, how ='outer' , on ='Customer ID',indicator = True)
om['_merge'].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
w1.merge(right = fd, how ='left' , on ='Food ID')
# Out:
#      Customer ID  Food ID   Food Item  Price
# 0            537        9       Donut   0.99
# 1             97        4  Quesadilla   4.25
# 2            658        1       Sushi   3.99
# 3            202        2     Burrito   9.99
# 4            155        9       Donut   0.99
# ..           ...      ...         ...    ...
# 245          413        9       Donut   0.99
# 246          926        6       Pasta  13.99
# 247          134        3        Taco   2.99
# 248          396        6       Pasta  13.99
# 249          535       10       Drink   1.75
#
# [250 rows x 4 columns]

# %%
fl = w1.merge(right = fd, how ='left' , on ='Food ID')
#type(fl['Customer ID'])             ----------------------------pandas.core.series.Series
fl['Customer ID'].value_counts()
# Out:
# 77     4
# 331    3
# 100    3
# 380    2
# 491    2
#       ..
# 315    1
# 313    1
# 737    1
# 821    1
# 514    1
# Name: Customer ID, Length: 221, dtype: int64

# %%
fl['Customer ID'].unique()
# Out:
# array([ 537,   97,  658,  202,  155,  213,  600,  503,   71,  174,  961,
#         966,  641,  288,  149,  954,  147,  550,  101,  549,   75,   78,
#         514,  833,  329,  586,  341,  519,  680,  419,   20,  822,  226,
#         203,   77,  628,  296,  821,  697,  264,  477,  524,  121,  290,
#         100,  260,  798,  462,  896,  953,  682,  809,  450,  772,  304,
#         159,  189,  876,  864,  799,   68,  812,   30,  921,  941,  108,
#         315,  358,  249,  491,  110,  737,  836,  749,  758,  527,  677,
#         741,  540,  433,  250,  504,  819,  910,  351,  282,  117,  937,
#          63,  144,  393,  380,  515,  233,  357,    3,  875,  352,   93,
#         323,   21,   64,  912,  327,  399,  459,  418,  669,  259,  816,
#         761,  410,   80,  363,  728,  479,  922,  244,  319,  909,  919,
#          51,   26,  472,  608,  160,  645,  574,  374,  762,   45,  332,
#         338,  140,  567,  602,   10,   74, 1000,  529,  881,  673,  107,
# ...

# %%
w2.merge(right = cust, how ='left' , left_on = "Customer ID", right_on = 'ID') #,validate = 'm:1'
# Out:
#      Customer ID  Food ID   ID First Name   Last Name  Gender       Company  \
# 0            688       10  688       Carl  Williamson    Male    Thoughtmix
# 1            813        7  813     Johnny      Walker    Male        Kayveo
# 2            495       10  495    Deborah      Little  Female    Babbleblab
# 3            189        5  189      Roger      Gordon    Male       Skilith
# 4            267        3  267    Matthew        Wood    Male        Agimba
# ..           ...      ...  ...        ...         ...     ...           ...
# 245          783       10  783    Phyllis       Meyer  Female        Voolia
# 246          556       10  556     Samuel      Bailey    Male        Oyoloo
# 247          547        9  547       Tina     Watkins  Female  Thoughtstorm
# 248          252        9  252    Douglas      Powell    Male       Jetwire
# 249          249        6  249    Anthony   Carpenter    Male    Shuffletag
#
#                       Occupation
# ...

# %%
c = cust.set_index('ID')
c.head(5)
# Out:
#    First Name Last Name  Gender  Company                     Occupation
# ID
# 1      Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 2    Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 3       Roger     Black    Male  Tagfeed              Account Executive
# 4      Steven     Evans    Male     Fatz               Registered Nurse
# 5        Judy  Morrison  Female  Demivee                Legal Assistant

# %%
f = fd.set_index('Food ID')
f.head(5)
# Out:
#           Food Item  Price
# Food ID
# 1             Sushi   3.99
# 2           Burrito   9.99
# 3              Taco   2.99
# 4        Quesadilla   4.25
# 5             Pizza   2.49

# %%
w1.merge(right = c, how ='left' , left_on = "Customer ID", right_index = True)  

# Merges Customer ID from left to indexes on right(ID)
# Out:
#      Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0            537        9     Cheryl   Carroll  Female   Zoombeat
# 1             97        4     Amanda   Watkins  Female        Ozu
# 2            658        1    Patrick      Webb    Male  Browsebug
# 3            202        2      Louis  Campbell    Male  Rhynoodle
# 4            155        9    Carolyn      Diaz  Female   Gigazoom
# ..           ...      ...        ...       ...     ...        ...
# 245          413        9      Diane    Bailey  Female    Wikibox
# 246          926        6       Anne    Wagner  Female      Skyba
# 247          134        3      Diana      Hall  Female      Quinu
# 248          396        6       Juan    Romero    Male    Zoonder
# 249          535       10      Nancy       Cox  Female     Trudeo
#
#                         Occupation
# 0                 Registered Nurse
# 1              Account Coordinator
# 2    Community Outreach Specialist
# ...

# %% [markdown]
# # Date

# %%
import datetime as dt
import pandas as pd

# %%
dob = dt.date(1993,2,2)

# %%
dob.month    #weekday,year,day,min=(1,1,1), max= (9999,12,31)
# Out:
# 2

# %%
dt.datetime(1993,2,2,3,4,56)
# Out:
# datetime.datetime(1993, 2, 2, 3, 4, 56)

# %%
str(dt.datetime(1993,2,2,3,4,56))
# Out:
# '1993-02-02 03:04:56'

# %%
dt.datetime(1993,2,2,3,4,56).hour
# Out:
# 3

# %%
pd.Timestamp("09/02/2080")
pd.Timestamp("09-02-2080")
# Out:
# Timestamp('2080-09-02 00:00:00')

# %%
dates = pd.Series(['July4,1994','03-09-2032','Ninetyfour','31-02-1998'])
dates
# Out:
# 0    July4,1994
# 1    03-09-2032
# 2    Ninetyfour
# 3    31-02-1998
# dtype: object

# %%
pd.to_datetime(dates,errors = 'coerce')  # Fills with Not a time
# Out:
# 0   1994-07-04
# 1   2032-03-09
# 2          NaT
# 3          NaT
# dtype: datetime64[ns]

# %% [markdown]
# **date_range(start,end,period,freq)**

# %%
pd.date_range(start = '01-01-1993',end = '01-10-1993',freq = '2D')    #'B'- Business Days(no Saturday,sunday)
# Out:
# DatetimeIndex(['1993-01-01', '1993-01-03', '1993-01-05', '1993-01-07',
#                '1993-01-09'],
#               dtype='datetime64[ns]', freq='2D')

# %%
pd.date_range(start = '01-01-1993',end = '01-10-1993',freq = 'W-FRI')  # MS - months
# Out:
# DatetimeIndex(['1993-01-01', '1993-01-08'], dtype='datetime64[ns]', freq='W-FRI')

# %%
pd.date_range(start = '01-01-1993',periods = 25 ,freq = '1D') 
# 25 days from 1/1/93
# Out:
# DatetimeIndex(['1993-01-01', '1993-01-02', '1993-01-03', '1993-01-04',
#                '1993-01-05', '1993-01-06', '1993-01-07', '1993-01-08',
#                '1993-01-09', '1993-01-10', '1993-01-11', '1993-01-12',
#                '1993-01-13', '1993-01-14', '1993-01-15', '1993-01-16',
#                '1993-01-17', '1993-01-18', '1993-01-19', '1993-01-20',
#                '1993-01-21', '1993-01-22', '1993-01-23', '1993-01-24',
#                '1993-01-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start = '01-01-1993',periods = 2 ,freq = 'A-JAN') # A - year, # H - hour
# Out:
# DatetimeIndex(['1993-01-31', '1994-01-31'], dtype='datetime64[ns]', freq='A-JAN')

# %%
pd.date_range(end = '01-01-1993',periods = 3 ,freq = '1D')
# Out:
# DatetimeIndex(['1992-12-30', '1992-12-31', '1993-01-01'], dtype='datetime64[ns]', freq='D')

# %% [markdown]
# **.dt** if you want to use date attributes on series

# %%
d10 = pd.date_range(end = '01-01-1993',periods = 10 ,freq = '1D')

# %%
d10s = pd.Series(d10)
d10s.head(2)
# Out:
# 0   1992-12-23
# 1   1992-12-24
# dtype: datetime64[ns]

# %%
d10s.dt.day     #month,day,year,date,dayoftheweak,is_start_of_quarter
# Out:
# 0    23
# 1    24
# 2    25
# 3    26
# 4    27
# 5    28
# 6    29
# 7    30
# 8    31
# 9     1
# dtype: int64

# %%
import pandas as pd
from pandas_datareader import data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-371-c75f15d9c9e2> in <module>
#       1 import pandas as pd
# ----> 2 from pandas_datareader import data
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %% [markdown]
# # Timestamp attributes (Indatetime index)

# %%
bdd = pd.read_csv(r"C:\Users\RAHUL RAJ\Desktop\ML_Practise\bigmac.csv")
bdd.head(3)
# Out:
#          date currency_code       name  local_price  dollar_ex  dollar_price
# 0  2000-04-01           ARS  Argentina         2.50       1.00      2.500000
# 1  2000-04-01           AUD  Australia         2.59       1.68      1.541667
# 2  2000-04-01           BRL     Brazil         2.95       1.79      1.648045

# %%
bdd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1330 non-null   object
#  1   currency_code  1330 non-null   object
#  2   name           1330 non-null   object
#  3   local_price    1330 non-null   float64
#  4   dollar_ex      1330 non-null   float64
#  5   dollar_price   1330 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 62.5+ KB

# %%
bdd ['date'] = pd.to_datetime(bdd['date'])

# %%
bdd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1330 non-null   datetime64[ns]
#  1   currency_code  1330 non-null   object
#  2   name           1330 non-null   object
#  3   local_price    1330 non-null   float64
#  4   dollar_ex      1330 non-null   float64
#  5   dollar_price   1330 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 62.5+ KB

# %%
bdd.set_index('date',inplace = True)

# %%
bdd.head(3)
# Out:
#            currency_code       name  local_price  dollar_ex  dollar_price
# date
# 2000-04-01           ARS  Argentina         2.50       1.00      2.500000
# 2000-04-01           AUD  Australia         2.59       1.68      1.541667
# 2000-04-01           BRL     Brazil         2.95       1.79      1.648045

# %%
bdd.index
# Out:
# DatetimeIndex(['2000-04-01', '2000-04-01', '2000-04-01', '2000-04-01',
#                '2000-04-01', '2000-04-01', '2000-04-01', '2000-04-01',
#                '2000-04-01', '2000-04-01',
#                ...
#                '2020-01-14', '2020-01-14', '2020-01-14', '2020-01-14',
#                '2020-01-14', '2020-01-14', '2020-01-14', '2020-01-14',
#                '2020-01-14', '2020-01-14'],
#               dtype='datetime64[ns]', name='date', length=1330, freq=None)

# %%
type(bdd.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
sd = bdd.index[0]
sd
# Out:
# Timestamp('2000-04-01 00:00:00')

# %%
sd.month  #week, day, year, is_month_start,is_month_end, is_quater_start, is_quater_end
# Out:
# 4

# %%
sd.month_name()
# Out:
# 'April'

# %%
bdd.index.day_name()
# Out:
# Index(['Saturday', 'Saturday', 'Saturday', 'Saturday', 'Saturday', 'Saturday',
#        'Saturday', 'Saturday', 'Saturday', 'Saturday',
#        ...
#        'Tuesday', 'Tuesday', 'Tuesday', 'Tuesday', 'Tuesday', 'Tuesday',
#        'Tuesday', 'Tuesday', 'Tuesday', 'Tuesday'],
#       dtype='object', name='date', length=1330)

# %%
bdd.insert(0,'day_name',value = bdd.index.day_name() )

# %%
bdd
# Out:
#             day_name currency_code           name  local_price  dollar_ex  \
# date
# 2000-04-01  Saturday           ARS      Argentina         2.50      1.000
# 2000-04-01  Saturday           AUD      Australia         2.59      1.680
# 2000-04-01  Saturday           BRL         Brazil         2.95      1.790
# 2000-04-01  Saturday           CAD         Canada         2.85      1.470
# 2000-04-01  Saturday           CHF    Switzerland         5.90      1.700
# ...              ...           ...            ...          ...        ...
# 2020-01-14   Tuesday           UAH        Ukraine        57.00     23.990
# 2020-01-14   Tuesday           UYU        Uruguay       179.00     37.435
# 2020-01-14   Tuesday           USD  United States         5.67      1.000
# 2020-01-14   Tuesday           VND        Vietnam     66000.00  23176.000
# 2020-01-14   Tuesday           ZAR   South Africa        31.00     14.391
#
#             dollar_price
# date
# 2000-04-01      2.500000
# ...

# %% [markdown]
# # Going to find what was the price on New year

# %%
pd.date_range(start ='2000-01-01',end = '2021-01-01',freq = pd.DateOffset(years = 1))
# Out:
# DatetimeIndex(['2000-01-01', '2001-01-01', '2002-01-01', '2003-01-01',
#                '2004-01-01', '2005-01-01', '2006-01-01', '2007-01-01',
#                '2008-01-01', '2009-01-01', '2010-01-01', '2011-01-01',
#                '2012-01-01', '2013-01-01', '2014-01-01', '2015-01-01',
#                '2016-01-01', '2017-01-01', '2018-01-01', '2019-01-01',
#                '2020-01-01', '2021-01-01'],
#               dtype='datetime64[ns]', freq='<DateOffset: years=1>')

# %%
newyear = pd.date_range(start ='2000-01-01',end = '2021-01-01',freq = pd.DateOffset(years = 1))

# %%
bdd[bdd.index.isin(newyear)]
# Out:
#            day_name currency_code           name  local_price   dollar_ex  \
# date
# 2006-01-01   Sunday           ARS      Argentina         4.75      3.0638
# 2006-01-01   Sunday           AUD      Australia         3.25      1.3308
# 2006-01-01   Sunday           BRL         Brazil         6.20      2.2615
# 2006-01-01   Sunday           CAD         Canada         3.52      1.1704
# 2006-01-01   Sunday           CHF    Switzerland         6.30      1.2776
# ...             ...           ...            ...          ...         ...
# 2019-01-01  Tuesday           UAH        Ukraine        54.00     27.8000
# 2019-01-01  Tuesday           UYU        Uruguay       140.00     32.5100
# 2019-01-01  Tuesday           USD  United States         5.58      1.0000
# 2019-01-01  Tuesday           VND        Vietnam     65000.00  23199.0000
# 2019-01-01  Tuesday           ZAR   South Africa        31.00     13.8675
#
#             dollar_price
# date
# 2006-01-01      1.550362
# ...

# %%
bddny = bdd[bdd.index.isin(newyear)]

# %%
bddny.head()
# Out:
#            day_name currency_code         name  local_price  dollar_ex  \
# date
# 2006-01-01   Sunday           ARS    Argentina         4.75     3.0638
# 2006-01-01   Sunday           AUD    Australia         3.25     1.3308
# 2006-01-01   Sunday           BRL       Brazil         6.20     2.2615
# 2006-01-01   Sunday           CAD       Canada         3.52     1.1704
# 2006-01-01   Sunday           CHF  Switzerland         6.30     1.2776
#
#             dollar_price
# date
# 2006-01-01      1.550362
# 2006-01-01      2.442140
# 2006-01-01      2.741543
# 2006-01-01      3.007519
# 2006-01-01      4.931121

# %%
type(bddny)
# Out:
# pandas.core.frame.DataFrame

# %%
bddny[bddny.name == 'Argentina']
# Out:
#              day_name currency_code       name  local_price  dollar_ex  \
# date
# 2006-01-01     Sunday           ARS  Argentina         4.75    3.06380
# 2007-01-01     Monday           ARS  Argentina         8.25    3.08875
# 2010-01-01     Friday           ARS  Argentina         7.00    3.79850
# 2012-01-01     Sunday           ARS  Argentina        20.00    4.31350
# 2013-01-01    Tuesday           ARS  Argentina        19.00    4.97650
# 2014-01-01  Wednesday           ARS  Argentina        21.00    6.92125
# 2015-01-01   Thursday           ARS  Argentina        28.00    8.61000
# 2016-01-01     Friday           ARS  Argentina        33.00   13.80925
# 2017-01-01     Sunday           ARS  Argentina        55.00   15.85750
# 2018-01-01     Monday           ARS  Argentina        75.00   18.93750
# 2019-01-01    Tuesday           ARS  Argentina        75.00   37.45500
#
#             dollar_price
# date
# 2006-01-01      1.550362
# 2007-01-01      2.670983
# ...

# %%
bdd.index + pd.DateOffset(months = 1)
# Out:
# DatetimeIndex(['2000-05-01', '2000-05-01', '2000-05-01', '2000-05-01',
#                '2000-05-01', '2000-05-01', '2000-05-01', '2000-05-01',
#                '2000-05-01', '2000-05-01',
#                ...
#                '2020-02-14', '2020-02-14', '2020-02-14', '2020-02-14',
#                '2020-02-14', '2020-02-14', '2020-02-14', '2020-02-14',
#                '2020-02-14', '2020-02-14'],
#               dtype='datetime64[ns]', name='date', length=1330, freq=None)

# %%
bdd.index + pd.tseries.offsets.MonthEnd()   # it returns th end of that month

# from pandas.tseries import offsets
# Out:
# DatetimeIndex(['2000-04-30', '2000-04-30', '2000-04-30', '2000-04-30',
#                '2000-04-30', '2000-04-30', '2000-04-30', '2000-04-30',
#                '2000-04-30', '2000-04-30',
#                ...
#                '2020-01-31', '2020-01-31', '2020-01-31', '2020-01-31',
#                '2020-01-31', '2020-01-31', '2020-01-31', '2020-01-31',
#                '2020-01-31', '2020-01-31'],
#               dtype='datetime64[ns]', name='date', length=1330, freq=None)

# %%
pd.Timestamp('2020-02-02') - pd.Timestamp('2020-03-04')
# Out:
# Timedelta('-31 days +00:00:00')

# %%
pd.Timestamp('2020-02-02')  + pd.Timedelta(days = 5,hours = 2,minutes= 30)
# Out:
# Timestamp('2020-02-07 02:30:00')

# %%
pd.Timedelta('14days 12 hours 57 minutes')
# Out:
# Timedelta('14 days 12:57:00')

# %%
ec = pd.read_csv('ecommerce.csv',index_col = 'ID',parse_dates = ['order_date','delivery_date'])
ec.head()
# Out:
#    order_date delivery_date
# ID
# 1  1998-05-24    1999-02-05
# 2  1992-04-22    1998-03-06
# 4  1991-02-10    1992-08-26
# 5  1992-07-21    1997-11-20
# 7  1993-09-02    1998-06-10

# %%
ec['Delivery (days)'] = ec['delivery_date'] - ec ['order_date']

# %%
ec.head()
# Out:
#    order_date delivery_date Delivery (days)
# ID
# 1  1998-05-24    1999-02-05        257 days
# 2  1992-04-22    1998-03-06       2144 days
# 4  1991-02-10    1992-08-26        563 days
# 5  1992-07-21    1997-11-20       1948 days
# 7  1993-09-02    1998-06-10       1742 days

# %% [markdown]
# **if we want to add 2 more days to every delivery ,then the new date is**

# %%
ec['New Delivery date(old+2)'] =  ec['delivery_date'] + pd.Timedelta(days = 2)

# %%
ec.head()
# Out:
#    order_date delivery_date Delivery (days) New Delivery date(old+2)
# ID
# 1  1998-05-24    1999-02-05        257 days               1999-02-07
# 2  1992-04-22    1998-03-06       2144 days               1998-03-08
# 4  1991-02-10    1992-08-26        563 days               1992-08-28
# 5  1992-07-21    1997-11-20       1948 days               1997-11-22
# 7  1993-09-02    1998-06-10       1742 days               1998-06-12

# %% [markdown]
# # INPUT ,OUTPUT

# %%
url = 'https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv?accessType=DOWNLOAD'

babynames = pd.read_csv(url)

# %%
babynames.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %%
type(babynames['Child\'s First Name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # SERIES To LIST

# %%
babynames['Child\'s First Name'].tolist()
# Out:
# ['GERALDINE',
#  'GIA',
#  'GIANNA',
#  'GISELLE',
#  'GRACE',
#  'GUADALUPE',
#  'HAILEY',
#  'HALEY',
#  'HANNAH',
#  'HAYLEE',
#  'HAYLEY',
#  'HAZEL',
#  'HEAVEN',
#  'HEIDI',
#  'HEIDY',
#  'HELEN',
#  'IMANI',
#  'INGRID',
#  'IRENE',
#  'IRIS',
#  'ISABEL',
#  'ISABELA',
#  'ISABELLA',
#  'ISABELLE',
#  'ISIS',
#  'ITZEL',
#  'IZABELLA',
#  'JACQUELINE',
#  'JADA',
#  'JADE',
#  'JAELYNN',
#  'JAMIE',
#  'JANELLE',
#  'JASLENE',
#  'JASMIN',
#  'JASMINE',
#  'JAYDA',
#  'JAYLA',
#  'JAYLAH',
#  'JAYLEEN',
#  'JAYLENE',
#  'JAYLIN',
#  'JAYLYN',
#  'JAZLYN',
#  'JAZMIN',
#  'JAZMINE',
#  'JENNIFER',
#  'JESSICA',
#  'JIMENA',
#  'JOCELYN',
#  'JOHANNA',
#  'JOSELYN',
#  'JULIA',
#  'JULIANA',
#  'JULIANNA',
#  'JULIET',
#  'JULIETTE',
#  'JULISSA',
#  'KAELYN',
#  'KAILEY',
#  'KAILYN',
#  'KAITLYN',
#  'KAMILA',
#  'KAREN',
#  'KARLA',
#  'KATE',
#  'KATELYN',
#  'KATELYNN',
#  'KATHERINE',
#  'KATIE',
#  'KAYLA',
#  'KAYLEE',
#  'KAYLEEN',
#  'KAYLEIGH',
#  'KAYLIE',
# ...

# %%
babynames['Child\'s First Name'].to_dict()  # make sure they are unique
# Out:
# {0: 'GERALDINE',
#  1: 'GIA',
#  2: 'GIANNA',
#  3: 'GISELLE',
#  4: 'GRACE',
#  5: 'GUADALUPE',
#  6: 'HAILEY',
#  7: 'HALEY',
#  8: 'HANNAH',
#  9: 'HAYLEE',
#  10: 'HAYLEY',
#  11: 'HAZEL',
#  12: 'HEAVEN',
#  13: 'HEIDI',
#  14: 'HEIDY',
#  15: 'HELEN',
#  16: 'IMANI',
#  17: 'INGRID',
#  18: 'IRENE',
#  19: 'IRIS',
#  20: 'ISABEL',
#  21: 'ISABELA',
#  22: 'ISABELLA',
#  23: 'ISABELLE',
#  24: 'ISIS',
#  25: 'ITZEL',
#  26: 'IZABELLA',
#  27: 'JACQUELINE',
#  28: 'JADA',
#  29: 'JADE',
#  30: 'JAELYNN',
#  31: 'JAMIE',
#  32: 'JANELLE',
#  33: 'JASLENE',
#  34: 'JASMIN',
#  35: 'JASMINE',
#  36: 'JAYDA',
#  37: 'JAYLA',
#  38: 'JAYLAH',
#  39: 'JAYLEEN',
#  40: 'JAYLENE',
#  41: 'JAYLIN',
#  42: 'JAYLYN',
#  43: 'JAZLYN',
#  44: 'JAZMIN',
#  45: 'JAZMINE',
#  46: 'JENNIFER',
#  47: 'JESSICA',
#  48: 'JIMENA',
#  49: 'JOCELYN',
#  50: 'JOHANNA',
#  51: 'JOSELYN',
#  52: 'JULIA',
#  53: 'JULIANA',
#  54: 'JULIANNA',
#  55: 'JULIET',
#  56: 'JULIETTE',
#  57: 'JULISSA',
# ...

# %%
'*'.join(['a' , 'b' ,'c'])
# Out:
# 'a*b*c'

# %%
type(babynames['Child\'s First Name'])
# Out:
# pandas.core.series.Series

# %%
', '.join(babynames['Child\'s First Name']).title()
# Out:
# "Geraldine, Gia, Gianna, Giselle, Grace, Guadalupe, Hailey, Haley, Hannah, Haylee, Hayley, Hazel, Heaven, Heidi, Heidy, Helen, Imani, Ingrid, Irene, Iris, Isabel, Isabela, Isabella, Isabelle, Isis, Itzel, Izabella, Jacqueline, Jada, Jade, Jaelynn, Jamie, Janelle, Jaslene, Jasmin, Jasmine, Jayda, Jayla, Jaylah, Jayleen, Jaylene, Jaylin, Jaylyn, Jazlyn, Jazmin, Jazmine, Jennifer, Jessica, Jimena, Jocelyn, Johanna, Joselyn, Julia, Juliana, Julianna, Juliet, Juliette, Julissa, Kaelyn, Kailey, Kailyn, Kaitlyn, Kamila, Karen, Karla, Kate, Katelyn, Katelynn, Katherine, Katie, Kayla, Kaylee, Kayleen, Kayleigh, Kaylie, Kaylin, Keily, Kelly, Keyla, Khloe, Kiara, Kimberly, Krystal, Kylee, Kylie, Laila, Laura, Lauren, Layla, Lea, Leah, Leila, Leilani, Lesley, Leslie, Lesly, Leyla, Lia, Liana, Liliana, Lily, Lindsay, Lizbeth, London, Lucia, Luna, Luz, Madeline, Madelyn, Madison, Makayla, Maria, Mariah, Mariana, Marilyn, Marisol, Maya, Megan, Melanie, Melany, Melissa, Melody, Mia, Miah, Michelle, 
# ...

# %%
# babynames.to_csv('newname.csv',Index = False , columns = ['which columsn you want to export'])

# %% [markdown]
# # install xlrd , openpyxl

# %%
ds = pd.read_excel('Data - Single Worksheet.xlsx')
ds.head()
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
mds = pd.read_excel('Data - Multiple Worksheets.xlsx',sheet_name =1)#sheet name can be index or name of the sheet or even list
mds.head()
# Out:
#   First Name Last Name           City Gender
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
dds =pd.read_excel('Data - Multiple Worksheets.xlsx',sheet_name = [ 'Data 1', 'Data 2']) #sheetname = None imports all sheets
dds
# Out:
# {'Data 1':   First Name Last Name           City Gender
#  0    Brandon     James          Miami      M
#  1       Sean   Hawkins         Denver      M
#  2       Judy       Day    Los Angeles      F
#  3     Ashley      Ruiz  San Francisco      F
#  4  Stephanie     Gomez       Portland      F,
#  'Data 2':   First Name Last Name           City Gender
#  0     Parker     Power        Raleigh      F
#  1    Preston  Prescott   Philadelphia      F
#  2    Ronaldo   Donaldo         Bangor      M
#  3      Megan   Stiller  San Francisco      M
#  4     Bustin    Jieber         Austin      F}

# %%
type(dds)
# Out:
# dict

# %%
dds['Data 1']
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
dds['Data 2']
# Out:
#   First Name Last Name           City Gender
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
boys = babynames[babynames['Gender'] == 'MALE']
girls =  babynames[babynames['Gender'] == 'FEMALE']

# %%
excel_file = pd.ExcelWriter('babynames.xlsx')

# %%
boys.to_excel(excel_file, sheet_name = 'boys',index = False)

# %%
girls.to_excel(excel_file, sheet_name = 'girls',index = False)

# %%
excel_file.save()

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

# %%
jb.head()
# Out:
#                       Year  Years lapse        Bond actor  \
# Film
# A View to a Kill      1985          2.0       Roger Moore
# Casino Royale         2006          4.0      Daniel Craig
# Diamonds Are Forever  1971          2.0  Sir Sean Connery
# Die Another Day       2002          3.0    Pierce Brosnan
# Dr. No                1962          NaN  Sir Sean Connery
#
#                       Bond actor appearance  Villians Dispatched  \
# Film
# A View to a Kill                          7                    5
# Casino Royale                             1                   11
# Diamonds Are Forever                      6                    7
# Die Another Day                           4                   31
# Dr. No                                    1                    4
#
#                       Others' Dispatched  Adjusted box office  \
# Film
# A View to a Kill                      57                275.2
# Casino Royale                         11                581.5
# ...

# %%
jb.plot(y ='Actual box office')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('dark_background')

jb.plot(y ='Actual box office')

# %% [markdown]
# .plt(kind = bar/pie)

# %% [markdown]
# # Options in pandas

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
pd.options.display.max_columns = 5

# %%
jb
# Out:
#                                  Year  Years lapse  ... Rating  \
# Film                                                ...
# A View to a Kill                 1985          2.0  ...     PG
# Casino Royale                    2006          4.0  ...  PG-13
# Diamonds Are Forever             1971          2.0  ...     PG
# Die Another Day                  2002          3.0  ...  PG-13
# Dr. No                           1962          NaN  ...     PG
# For Your Eyes Only               1981          2.0  ...     PG
# From Russia With Love            1963          1.0  ...     PG
# GoldenEye                        1995          6.0  ...  PG-13
# Goldfinger                       1964          1.0  ...     PG
# Licence to Kill                  1989          2.0  ...      R
# Live and Let Die                 1973          2.0  ...     PG
# Moonraker                        1979          2.0  ...     PG
# Octopussy                        1983          2.0  ...     PG
# ...

# %%
pd.get_option('max_columns')
# Out:
# 5

# %% [markdown]
# **pd.set_option('max_columns') = 10 \
#  pd.reset_option()**

# %%
pd.describe_option('max_columns')
# Out:
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 20] [currently: 5]

# %%
pd.get_option('precision')
# Out:
# 6

# %%
pd.set_option('precision', 2)

# %%
jb.head()
# Out:
#                       Year  Years lapse  ... Rating  Bond, James Bond said
# Film                                     ...
# A View to a Kill      1985          2.0  ...     PG                      2
# Casino Royale         2006          4.0  ...  PG-13                      1
# Diamonds Are Forever  1971          2.0  ...     PG                      1
# Die Another Day       2002          3.0  ...  PG-13                      1
# Dr. No                1962          NaN  ...     PG                      1
#
# [5 rows x 24 columns]
